# %%
from typing import Any

import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
from torchvision.transforms import ToPILImage

from anomalib.data import MVTec
from anomalib.data.utils import read_image
from anomalib.deploy import ExportType, OpenVINOInferencer
from anomalib.engine import Engine
from anomalib.models import Padim
from anomalib.utils.visualization import ImageResult
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# INFO:numexpr.utils:NumExpr defaulting to 16 threads.

# %%
datamodule = MVTec(num_workers=0)
datamodule.prepare_data()  # Downloads the dataset if it's not in the specified `root` directory
datamodule.setup()  # Create train/val/test/prediction sets.

i, data = next(enumerate(datamodule.val_dataloader()))
print(type(data))
# Out:
# INFO:anomalib.data.utils.download:Downloading the mvtec dataset.
# mvtec:  32%|███▏      | 1.66G/5.26G [00:53<01:55, 31.2MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 datamodule = MVTec(num_workers=0)
# ----> 2 datamodule.prepare_data()  # Downloads the dataset if it's not in the specified `root` directory
#       3 datamodule.setup()  # Create train/val/test/prediction sets.
#       5 i, data = next(enumerate(datamodule.val_dataloader()))
#
# File /workspaces/eng-ai-agents/.venv/lib/python3.11/site-packages/anomalib/data/image/mvtec.py:414, in MVTec.prepare_data(self)
#     412     logger.info("Found the dataset.")
#     413 else:
# --> 414     download_and_extract(self.root, DOWNLOAD_INFO)
#
# File /workspaces/eng-ai-agents/.venv/lib/python3.11/site-packages/anomalib/data/utils/download.py:335, in download_and_extract(root, info)
#     333 if info.url.startswith("http://") or info.url.startswith("https://"):
#     334     with DownloadProgressBar(unit="B", unit_scale=True, miniters=1, desc=info.name) as progress_bar:
# --> 335         urlretrieve(  # noqa: S310  # nosec B310
#     336             url=f"{info.url}",
#     337             filename=downloaded_file_path,
#     338             reporthook=progress_bar.update_to,
#     339         )
#     340     logger.info("Checking the hash of the downloaded file.")
#     341     check_hash(downloaded_file_path, info.hashsum)
#
# File /opt/rye/py/cpython@3.11.9/lib/python3.11/urllib/request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File /opt/rye/py/cpython@3.11.9/lib/python3.11/http/client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File /opt/rye/py/cpython@3.11.9/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/rye/py/cpython@3.11.9/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/rye/py/cpython@3.11.9/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
