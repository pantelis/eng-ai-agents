# %% [markdown]
# ## Visual SLAM
#
# ### Introduction
#
# Visual SLAM (Simultaneous Localization and Mapping) combines visual feature detection and tracking with pose graph optimization to simultaneously build a map of the environment and estimate the camera's trajectory within it. VSLAM is particularly useful in GPS-denied environments such as indoor spaces, tunnels, and dense urban areas.
#
# ### Prerequisites
#
# - Docker installed on your workstation
# - A webcam or USB camera
# - Familiarity with ORB features and camera geometry
#
# ---
#
# ### Task 1: Understand VSLAM from First Principles
#
# To fully understand how VSLAM works under the hood, follow the two lecture videos below and implement a VSLAM pipeline in Python. You may use any combination of OpenCV, PyTorch, RVC3-Python, or FilterPy.
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/H_1OtbMD-sE" frameBorder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowFullScreen></iframe>
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/TuJLOUxZKMQ" frameBorder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowFullScreen></iframe>
#
# Your implementation should demonstrate:
# - ORB (or similar) feature detection and matching
# - Essential matrix estimation and decomposition
# - Triangulation of 3D landmarks
# - Camera trajectory estimation
#
# Use the **KITTI odometry dataset** for evaluation, available [here](http://www.cvlibs.net/datasets/kitti/eval_odometry.php?benchmark=odometry). Compare your estimated trajectory against the ground truth.
#
# > **Note:** You may alternatively work with the [Python bindings of StellaVSLAM](https://github.com/Squiro/StellaVSLAM-Python-bindings), but you must understand the associated C++ code and document what each called C++ function does in your report.
#
# ---
#
# ### Task 2: VSLAM on Your Own Indoor Space
#
# [StellaVSLAM](https://github.com/stella-cv/stella_vslam) is a maintained fork of OpenVSLAM — a flexible visual SLAM system that supports monocular, stereo, and RGB-D inputs. It uses [ORB (Oriented FAST and Rotated BRIEF)](https://docs.opencv.org/4.10.0/d1/d89/tutorial_py_orb.html) features to detect, track, and map the environment in 3D.
#
# First, validate your setup by running the [Equirectangular Datasets](https://stella-cv.readthedocs.io/en/latest/simple_tutorial.html#equirectangular-datasets) example with the `aist_living_lab_1` video following the [Docker instructions](https://stella-cv.readthedocs.io/en/latest/docker.html). The video below shows the expected end result:
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/4uiyShM1BXg" frameBorder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowFullScreen></iframe>
#
# Then run VSLAM on your own space:
#
# 1. Record a video of your own indoor space (room, dorm, lab) using your laptop webcam or a USB camera. Walk slowly, covering the space from multiple viewpoints.
#
# 2. Follow [these instructions for UVC cameras](https://stella-cv.readthedocs.io/en/latest/example.html#slam-with-uvc-camera) to run StellaVSLAM on your video.
#
# 3. Create a camera configuration YAML file using calibration parameters from the [Camera Calibration](/aiml-common/lectures/sensor-models/cameras/camera-calibration) lecture. Use `example/aist/equirectangular.yaml` as a template, replacing the camera matrix and distortion coefficients with your own values.
#
# 4. **Publish a demo video** on your YouTube channel explaining and showcasing the reconstruction of your space.
#
# ---
#
# ### Task 3: Integrate StellaVSLAM with Nav2 (Extra Credit)
#
# Integrate StellaVSLAM into the ROS 2 navigation stack and demonstrate that it can work with Nav2 to navigate the TurtleBot in the maze **without a prior map**.
#
# This showcases the principles of Recursive State Estimation (RSE) — using visual landmarks and additional algorithms to achieve globally consistent localization without a-priori knowledge of the environment.
#
# Document your integration in tutorial format, as it will be used in a class setting.
#
# ---
#
# ### Deliverables
#
# 1. This notebook with all cells executed.
# 2. Python VSLAM implementation with trajectory plots overlaid on KITTI ground truth (Task 1).
# 3. Screenshots/recordings of StellaVSLAM running on both the reference dataset and your own space (Task 2).
# 4. YouTube video link for Task 2.
# 5. (Extra credit) ROS 2 integration tutorial and demo video (Task 3).
#
# ---
#
# > **Note:** This assignment requires calibrated camera intrinsic parameters. See the [Camera Calibration](/aiml-common/lectures/sensor-models/cameras/camera-calibration) page for the full calibration workflow, including Zhang's method and the OpenCV reference solution.
